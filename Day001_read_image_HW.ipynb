# %% [markdown]
# # 作業
#
# 思考一下我們前面有提到圖片是矩陣，但維度可能會不一樣
# 例如灰階圖只有兩個維度，RGB 彩圖則有 3 個維度
#
# 假如今天我們把 RGB 3 個維度拆開來看會有甚麼不同的效果呢？

# %% [markdown]
# 把rgb三個維度分開來看，可以看到只有綠色漸層或紅色漸層或藍色層的圖片，rgb是這三色維度相加後的結果

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt
import cv2 
img_path = 'D:\Jupyter\Part01\lena.png'
#img_path = 'lena.png'
# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
lenna_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
lenna_img[:,:,2]=0
lenna_img[:,:,0]=0
# Convert img to numpy array
cv2.imshow('bgr', lenna_img)
plt.imshow(lenna_img)
plt.show()

# %%
img_path = 'D:\Jupyter\Part01\lena.png'
#img_path = 'lena.png'
# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
lenna_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
lenna_img[:,:,2]=0
lenna_img[:,:,1]=0
# Convert img to numpy array
cv2.imshow('bgr', lenna_img)
plt.imshow(lenna_img)
plt.show()

# %%
img_path = 'D:\Jupyter\Part01\lena.png'
#img_path = 'lena.png'
# 以彩色圖片的方式載入
img = cv2.imread(img_path, cv2.IMREAD_COLOR)
lenna_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
lenna_img[:,:,0]=0
lenna_img[:,:,1]=0
# Convert img to numpy array
cv2.imshow('bgr', lenna_img)
plt.imshow(lenna_img)
plt.show()
