# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)

import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.
# 1.15.2
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive
# [Errno 2] No such file or directory: 'cupoy_cv_part4 # 可以自己改路徑'
# /content/gdrive/My Drive

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0065 - val_loss: 0.0023
#
# Epoch 00001: val_loss improved from inf to 0.00234, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0017 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00234 to 0.00189, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00003: val_loss improved from 0.00189 to 0.00188, saving model to best_weights.h5
# Epoch 4/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00004: val_loss improved from 0.00188 to 0.00182, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00005: val_loss improved from 0.00182 to 0.00181, saving model to best_weights.h5
# Epoch 6/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8180e-04 - val_loss: 0.0017
#
# Epoch 00006: val_loss improved from 0.00181 to 0.00174, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.2803e-04 - val_loss: 0.0016
#
# Epoch 00007: val_loss improved from 0.00174 to 0.00157, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 7.0470e-04 - val_loss: 0.0014
#
# Epoch 00008: val_loss improved from 0.00157 to 0.00139, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 6.2184e-04 - val_loss: 0.0013
#
# Epoch 00009: val_loss improved from 0.00139 to 0.00130, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.7521e-04 - val_loss: 0.0012
#
# Epoch 00010: val_loss improved from 0.00130 to 0.00118, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 5.1980e-04 - val_loss: 0.0011
#
# Epoch 00011: val_loss improved from 0.00118 to 0.00113, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.8011e-04 - val_loss: 0.0011
#
# Epoch 00012: val_loss improved from 0.00113 to 0.00107, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.5965e-04 - val_loss: 9.7850e-04
#
# Epoch 00013: val_loss improved from 0.00107 to 0.00098, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.2707e-04 - val_loss: 0.0010
#
# Epoch 00014: val_loss did not improve from 0.00098
# Epoch 15/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 4.0550e-04 - val_loss: 9.7865e-04
#
# Epoch 00015: val_loss did not improve from 0.00098
# Epoch 16/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.9137e-04 - val_loss: 9.1480e-04
#
# Epoch 00016: val_loss improved from 0.00098 to 0.00091, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.6677e-04 - val_loss: 8.7381e-04
#
# Epoch 00017: val_loss improved from 0.00091 to 0.00087, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.5511e-04 - val_loss: 8.7475e-04
#
# Epoch 00018: val_loss did not improve from 0.00087
# Epoch 19/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.4141e-04 - val_loss: 8.6807e-04
#
# Epoch 00019: val_loss improved from 0.00087 to 0.00087, saving model to best_weights.h5
# Epoch 20/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.3117e-04 - val_loss: 8.5726e-04
#
# Epoch 00020: val_loss improved from 0.00087 to 0.00086, saving model to best_weights.h5
# Epoch 21/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.2180e-04 - val_loss: 8.1174e-04
#
# Epoch 00021: val_loss improved from 0.00086 to 0.00081, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.0813e-04 - val_loss: 8.5283e-04
#
# Epoch 00022: val_loss did not improve from 0.00081
# Epoch 23/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 3.1147e-04 - val_loss: 8.2409e-04
#
# Epoch 00023: val_loss did not improve from 0.00081
# Epoch 24/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.9345e-04 - val_loss: 8.0400e-04
#
# Epoch 00024: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8111e-04 - val_loss: 7.7540e-04
#
# Epoch 00025: val_loss improved from 0.00080 to 0.00078, saving model to best_weights.h5
# Epoch 26/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.7898e-04 - val_loss: 7.7532e-04
#
# Epoch 00026: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 27/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.8488e-04 - val_loss: 7.8816e-04
#
# Epoch 00027: val_loss did not improve from 0.00078
# Epoch 28/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6997e-04 - val_loss: 7.9293e-04
#
# Epoch 00028: val_loss did not improve from 0.00078
# Epoch 29/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.6207e-04 - val_loss: 7.7979e-04
#
# Epoch 00029: val_loss did not improve from 0.00078
# Epoch 30/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.5156e-04 - val_loss: 7.7741e-04
#
# Epoch 00030: val_loss did not improve from 0.00078
# Epoch 31/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4240e-04 - val_loss: 7.9979e-04
#
# Epoch 00031: val_loss did not improve from 0.00078
# Epoch 32/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.4085e-04 - val_loss: 7.8455e-04
#
# Epoch 00032: val_loss did not improve from 0.00078
# Epoch 33/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3527e-04 - val_loss: 7.7462e-04
#
# Epoch 00033: val_loss improved from 0.00078 to 0.00077, saving model to best_weights.h5
# Epoch 34/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3225e-04 - val_loss: 7.8202e-04
#
# Epoch 00034: val_loss did not improve from 0.00077
# Epoch 35/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2502e-04 - val_loss: 7.4871e-04
#
# Epoch 00035: val_loss improved from 0.00077 to 0.00075, saving model to best_weights.h5
# Epoch 36/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.2382e-04 - val_loss: 7.9174e-04
#
# Epoch 00036: val_loss did not improve from 0.00075
# Epoch 37/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.3142e-04 - val_loss: 7.5148e-04
#
# Epoch 00037: val_loss did not improve from 0.00075
# Epoch 38/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1443e-04 - val_loss: 7.7590e-04
#
# Epoch 00038: val_loss did not improve from 0.00075
# Epoch 39/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1514e-04 - val_loss: 7.8274e-04
#
# Epoch 00039: val_loss did not improve from 0.00075
# Epoch 40/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0860e-04 - val_loss: 7.5454e-04
#
# Epoch 00040: val_loss did not improve from 0.00075
# Epoch 41/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0939e-04 - val_loss: 7.5188e-04
#
# Epoch 00041: val_loss did not improve from 0.00075
# Epoch 42/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.1158e-04 - val_loss: 7.3502e-04
#
# Epoch 00042: val_loss improved from 0.00075 to 0.00074, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 2.0584e-04 - val_loss: 7.6103e-04
#
# Epoch 00043: val_loss did not improve from 0.00074
# Epoch 44/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9783e-04 - val_loss: 7.4505e-04
#
# Epoch 00044: val_loss did not improve from 0.00074
# Epoch 45/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9913e-04 - val_loss: 7.2692e-04
#
# Epoch 00045: val_loss improved from 0.00074 to 0.00073, saving model to best_weights.h5
# Epoch 46/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9105e-04 - val_loss: 7.2554e-04
#
# Epoch 00046: val_loss improved from 0.00073 to 0.00073, saving model to best_weights.h5
# Epoch 47/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.9409e-04 - val_loss: 7.8557e-04
#
# Epoch 00047: val_loss did not improve from 0.00073
# Epoch 48/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8717e-04 - val_loss: 7.2738e-04
#
# Epoch 00048: val_loss did not improve from 0.00073
# Epoch 49/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8725e-04 - val_loss: 7.7365e-04
#
# Epoch 00049: val_loss did not improve from 0.00073
# Epoch 50/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8271e-04 - val_loss: 7.7677e-04
#
# Epoch 00050: val_loss did not improve from 0.00073
# Epoch 51/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8646e-04 - val_loss: 7.1919e-04
#
# Epoch 00051: val_loss improved from 0.00073 to 0.00072, saving model to best_weights.h5
# Epoch 52/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8164e-04 - val_loss: 7.3198e-04
#
# Epoch 00052: val_loss did not improve from 0.00072
# Epoch 53/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8223e-04 - val_loss: 7.5202e-04
#
# Epoch 00053: val_loss did not improve from 0.00072
# Epoch 54/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.8343e-04 - val_loss: 7.3412e-04
#
# Epoch 00054: val_loss did not improve from 0.00072
# Epoch 55/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7706e-04 - val_loss: 7.5501e-04
#
# Epoch 00055: val_loss did not improve from 0.00072
# Epoch 56/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7190e-04 - val_loss: 7.2014e-04
#
# Epoch 00056: val_loss did not improve from 0.00072
# Epoch 57/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6883e-04 - val_loss: 7.3525e-04
#
# Epoch 00057: val_loss did not improve from 0.00072
# Epoch 58/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6374e-04 - val_loss: 7.2723e-04
#
# Epoch 00058: val_loss did not improve from 0.00072
# Epoch 59/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.7453e-04 - val_loss: 7.6882e-04
#
# Epoch 00059: val_loss did not improve from 0.00072
# Epoch 60/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6494e-04 - val_loss: 7.2762e-04
#
# Epoch 00060: val_loss did not improve from 0.00072
# Epoch 61/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6590e-04 - val_loss: 7.5049e-04
#
# Epoch 00061: val_loss did not improve from 0.00072
# Epoch 62/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6034e-04 - val_loss: 7.3276e-04
#
# Epoch 00062: val_loss did not improve from 0.00072
# Epoch 63/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5665e-04 - val_loss: 7.1614e-04
#
# Epoch 00063: val_loss improved from 0.00072 to 0.00072, saving model to best_weights.h5
# Epoch 64/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.6113e-04 - val_loss: 7.3347e-04
#
# Epoch 00064: val_loss did not improve from 0.00072
# Epoch 65/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5669e-04 - val_loss: 7.2358e-04
#
# Epoch 00065: val_loss did not improve from 0.00072
# Epoch 66/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5613e-04 - val_loss: 7.5530e-04
#
# Epoch 00066: val_loss did not improve from 0.00072
# Epoch 67/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5696e-04 - val_loss: 7.3708e-04
#
# Epoch 00067: val_loss did not improve from 0.00072
# Epoch 68/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5960e-04 - val_loss: 7.1410e-04
#
# Epoch 00068: val_loss improved from 0.00072 to 0.00071, saving model to best_weights.h5
# Epoch 69/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5118e-04 - val_loss: 7.6586e-04
#
# Epoch 00069: val_loss did not improve from 0.00071
# Epoch 70/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.5208e-04 - val_loss: 7.1831e-04
#
# Epoch 00070: val_loss did not improve from 0.00071
# Epoch 71/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4676e-04 - val_loss: 7.1585e-04
#
# Epoch 00071: val_loss did not improve from 0.00071
# Epoch 72/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4414e-04 - val_loss: 7.3441e-04
#
# Epoch 00072: val_loss did not improve from 0.00071
# Epoch 73/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4818e-04 - val_loss: 7.3075e-04
#
# Epoch 00073: val_loss did not improve from 0.00071
# Epoch 74/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4601e-04 - val_loss: 7.1011e-04
#
# Epoch 00074: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 75/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4190e-04 - val_loss: 7.1429e-04
#
# Epoch 00075: val_loss did not improve from 0.00071
# Epoch 76/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4268e-04 - val_loss: 7.0509e-04
#
# Epoch 00076: val_loss improved from 0.00071 to 0.00071, saving model to best_weights.h5
# Epoch 77/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4092e-04 - val_loss: 7.4623e-04
#
# Epoch 00077: val_loss did not improve from 0.00071
# Epoch 78/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.4012e-04 - val_loss: 7.1175e-04
#
# Epoch 00078: val_loss did not improve from 0.00071
# Epoch 79/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3881e-04 - val_loss: 7.3311e-04
#
# Epoch 00079: val_loss did not improve from 0.00071
# Epoch 80/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3525e-04 - val_loss: 7.2849e-04
#
# Epoch 00080: val_loss did not improve from 0.00071
# Epoch 81/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3686e-04 - val_loss: 7.2640e-04
#
# Epoch 00081: val_loss did not improve from 0.00071
# Epoch 82/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3140e-04 - val_loss: 7.0148e-04
#
# Epoch 00082: val_loss improved from 0.00071 to 0.00070, saving model to best_weights.h5
# Epoch 83/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3223e-04 - val_loss: 7.1184e-04
#
# Epoch 00083: val_loss did not improve from 0.00070
# Epoch 84/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3154e-04 - val_loss: 7.6210e-04
#
# Epoch 00084: val_loss did not improve from 0.00070
# Epoch 85/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3457e-04 - val_loss: 7.4110e-04
#
# Epoch 00085: val_loss did not improve from 0.00070
# Epoch 86/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2794e-04 - val_loss: 7.1512e-04
#
# Epoch 00086: val_loss did not improve from 0.00070
# Epoch 87/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2940e-04 - val_loss: 7.0940e-04
#
# Epoch 00087: val_loss did not improve from 0.00070
# Epoch 88/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3048e-04 - val_loss: 7.0242e-04
#
# Epoch 00088: val_loss did not improve from 0.00070
# Epoch 89/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3028e-04 - val_loss: 6.9587e-04
#
# Epoch 00089: val_loss improved from 0.00070 to 0.00070, saving model to best_weights.h5
# Epoch 90/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.3197e-04 - val_loss: 7.3338e-04
#
# Epoch 00090: val_loss did not improve from 0.00070
# Epoch 91/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2348e-04 - val_loss: 7.1692e-04
#
# Epoch 00091: val_loss did not improve from 0.00070
# Epoch 92/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2654e-04 - val_loss: 7.0460e-04
#
# Epoch 00092: val_loss did not improve from 0.00070
# Epoch 93/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2263e-04 - val_loss: 6.9975e-04
#
# Epoch 00093: val_loss did not improve from 0.00070
# Epoch 94/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2623e-04 - val_loss: 7.2236e-04
#
# Epoch 00094: val_loss did not improve from 0.00070
# Epoch 95/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.2282e-04 - val_loss: 7.3801e-04
#
# Epoch 00095: val_loss did not improve from 0.00070
# Epoch 96/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1918e-04 - val_loss: 6.9611e-04
#
# Epoch 00096: val_loss did not improve from 0.00070
# Epoch 97/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1802e-04 - val_loss: 7.1542e-04
#
# Epoch 00097: val_loss did not improve from 0.00070
# Epoch 98/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1902e-04 - val_loss: 7.1539e-04
#
# Epoch 00098: val_loss did not improve from 0.00070
# Epoch 99/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1495e-04 - val_loss: 7.1552e-04
#
# Epoch 00099: val_loss did not improve from 0.00070
# Epoch 100/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1740e-04 - val_loss: 7.3638e-04
#
# Epoch 00100: val_loss did not improve from 0.00070
# Epoch 101/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1979e-04 - val_loss: 7.2680e-04
#
# Epoch 00101: val_loss did not improve from 0.00070
# Epoch 102/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1804e-04 - val_loss: 7.0331e-04
#
# Epoch 00102: val_loss did not improve from 0.00070
# Epoch 103/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1539e-04 - val_loss: 7.1243e-04
#
# Epoch 00103: val_loss did not improve from 0.00070
# Epoch 104/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1365e-04 - val_loss: 7.1902e-04
#
# Epoch 00104: val_loss did not improve from 0.00070
# Epoch 105/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1110e-04 - val_loss: 7.3902e-04
#
# Epoch 00105: val_loss did not improve from 0.00070
# Epoch 106/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0927e-04 - val_loss: 7.2423e-04
#
# Epoch 00106: val_loss did not improve from 0.00070
# Epoch 107/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0748e-04 - val_loss: 7.1458e-04
#
# Epoch 00107: val_loss did not improve from 0.00070
# Epoch 108/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0781e-04 - val_loss: 7.0871e-04
#
# Epoch 00108: val_loss did not improve from 0.00070
# Epoch 109/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0943e-04 - val_loss: 7.2905e-04
#
# Epoch 00109: val_loss did not improve from 0.00070
# Epoch 110/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0838e-04 - val_loss: 7.2728e-04
#
# Epoch 00110: val_loss did not improve from 0.00070
# Epoch 111/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0830e-04 - val_loss: 7.0686e-04
#
# Epoch 00111: val_loss did not improve from 0.00070
# Epoch 112/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0583e-04 - val_loss: 7.0357e-04
#
# Epoch 00112: val_loss did not improve from 0.00070
# Epoch 113/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0935e-04 - val_loss: 7.0400e-04
#
# Epoch 00113: val_loss did not improve from 0.00070
# Epoch 114/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0446e-04 - val_loss: 6.9424e-04
#
# Epoch 00114: val_loss improved from 0.00070 to 0.00069, saving model to best_weights.h5
# Epoch 115/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.1320e-04 - val_loss: 7.0675e-04
#
# Epoch 00115: val_loss did not improve from 0.00069
# Epoch 116/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0779e-04 - val_loss: 7.0092e-04
#
# Epoch 00116: val_loss did not improve from 0.00069
# Epoch 117/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0232e-04 - val_loss: 7.0563e-04
#
# Epoch 00117: val_loss did not improve from 0.00069
# Epoch 118/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0484e-04 - val_loss: 7.0807e-04
#
# Epoch 00118: val_loss did not improve from 0.00069
# Epoch 119/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0088e-04 - val_loss: 7.2308e-04
#
# Epoch 00119: val_loss did not improve from 0.00069
# Epoch 120/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0202e-04 - val_loss: 7.2362e-04
#
# Epoch 00120: val_loss did not improve from 0.00069
# Epoch 121/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9181e-05 - val_loss: 7.2719e-04
#
# Epoch 00121: val_loss did not improve from 0.00069
# Epoch 122/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8560e-05 - val_loss: 7.1933e-04
#
# Epoch 00122: val_loss did not improve from 0.00069
# Epoch 123/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0008e-04 - val_loss: 7.3201e-04
#
# Epoch 00123: val_loss did not improve from 0.00069
# Epoch 124/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9543e-05 - val_loss: 7.5250e-04
#
# Epoch 00124: val_loss did not improve from 0.00069
# Epoch 125/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9775e-05 - val_loss: 7.3237e-04
#
# Epoch 00125: val_loss did not improve from 0.00069
# Epoch 126/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8223e-05 - val_loss: 7.1892e-04
#
# Epoch 00126: val_loss did not improve from 0.00069
# Epoch 127/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.8914e-05 - val_loss: 7.3259e-04
#
# Epoch 00127: val_loss did not improve from 0.00069
# Epoch 128/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.5467e-05 - val_loss: 7.1598e-04
#
# Epoch 00128: val_loss did not improve from 0.00069
# Epoch 129/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7110e-05 - val_loss: 7.1337e-04
#
# Epoch 00129: val_loss did not improve from 0.00069
# Epoch 130/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6502e-05 - val_loss: 7.3061e-04
#
# Epoch 00130: val_loss did not improve from 0.00069
# Epoch 131/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.9704e-05 - val_loss: 7.2807e-04
#
# Epoch 00131: val_loss did not improve from 0.00069
# Epoch 132/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 1.0008e-04 - val_loss: 7.3798e-04
#
# Epoch 00132: val_loss did not improve from 0.00069
# Epoch 133/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.7024e-05 - val_loss: 7.0226e-04
#
# Epoch 00133: val_loss did not improve from 0.00069
# Epoch 134/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.4229e-05 - val_loss: 7.1447e-04
#
# Epoch 00134: val_loss did not improve from 0.00069
# Epoch 135/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3990e-05 - val_loss: 7.0964e-04
#
# Epoch 00135: val_loss did not improve from 0.00069
# Epoch 136/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.6917e-05 - val_loss: 7.2869e-04
#
# Epoch 00136: val_loss did not improve from 0.00069
# Epoch 137/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2657e-05 - val_loss: 6.9457e-04
#
# Epoch 00137: val_loss did not improve from 0.00069
# Epoch 138/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.2901e-05 - val_loss: 7.0593e-04
#
# Epoch 00138: val_loss did not improve from 0.00069
# Epoch 139/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.1727e-05 - val_loss: 7.0718e-04
#
# Epoch 00139: val_loss did not improve from 0.00069
# Epoch 140/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.3197e-05 - val_loss: 7.3181e-04
#
# Epoch 00140: val_loss did not improve from 0.00069
# Epoch 141/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0605e-05 - val_loss: 7.5939e-04
#
# Epoch 00141: val_loss did not improve from 0.00069
# Epoch 142/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9003e-05 - val_loss: 7.2024e-04
#
# Epoch 00142: val_loss did not improve from 0.00069
# Epoch 143/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.9814e-05 - val_loss: 7.0872e-04
#
# Epoch 00143: val_loss did not improve from 0.00069
# Epoch 144/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8269e-05 - val_loss: 7.3700e-04
#
# Epoch 00144: val_loss did not improve from 0.00069
# Epoch 145/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 9.0443e-05 - val_loss: 7.2602e-04
#
# Epoch 00145: val_loss did not improve from 0.00069
# Epoch 146/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.7044e-05 - val_loss: 7.0957e-04
#
# Epoch 00146: val_loss did not improve from 0.00069
# Epoch 147/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.7055e-05 - val_loss: 7.3107e-04
#
# Epoch 00147: val_loss did not improve from 0.00069
# Epoch 148/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.7294e-05 - val_loss: 7.2650e-04
#
# Epoch 00148: val_loss did not improve from 0.00069
# Epoch 149/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8323e-05 - val_loss: 6.9474e-04
#
# Epoch 00149: val_loss did not improve from 0.00069
# Epoch 150/150
# 1712/1712 [==============================] - 14s 8ms/step - loss: 8.8695e-05 - val_loss: 7.2948e-04
#
# Epoch 00150: val_loss did not improve from 0.00069

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
# model checkpoint 
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)
# training the model
'''
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
'''


hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, nb_epoch = 20, callbacks=[checkpoint, hist], shuffle=True, validation_data=(train_X, points_train))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
#   if sys.path[0] == '':
# Epoch 1/20
# 66/66 [==============================] - 24s 358ms/step - loss: 0.0048 - val_loss: 0.0015
#
# Epoch 00001: val_loss did not improve from 0.00069
# Epoch 2/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0015 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00069
# Epoch 3/20
# 66/66 [==============================] - 23s 343ms/step - loss: 0.0014 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00069
# Epoch 4/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00069
# Epoch 5/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00069
# Epoch 6/20
# 66/66 [==============================] - 23s 343ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00069
# Epoch 7/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00069
# Epoch 8/20
# 66/66 [==============================] - 23s 341ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00069
# Epoch 9/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00069
# Epoch 10/20
# 66/66 [==============================] - 23s 343ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00069
# Epoch 11/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00069
# Epoch 12/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00069
# Epoch 13/20
# 66/66 [==============================] - 23s 343ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00069
# Epoch 14/20
# 66/66 [==============================] - 22s 341ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00069
# Epoch 15/20
# 66/66 [==============================] - 22s 340ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00069
# Epoch 16/20
# 66/66 [==============================] - 23s 341ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00069
# Epoch 17/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00069
# Epoch 18/20
# 66/66 [==============================] - 23s 341ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00069
# Epoch 19/20
# 66/66 [==============================] - 22s 341ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00069
# Epoch 20/20
# 66/66 [==============================] - 23s 342ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00069

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
